# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
var=sns.load_dataset('tips')
#print(var)
sns.catplot(x="total_bill",y="tip",data=var,kind="point",height=35)
plt.show()
