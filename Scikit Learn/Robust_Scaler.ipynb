# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
import seaborn as sns
data=pd.read_csv(r'C:\Users\KIIT0001\Desktop\Python Practice\CSV\submission.csv')
d1=data['O2_2'].iloc[0:20].values.reshape(-1,1)
sns.boxplot(data=d1,color="#0743C4")
rs=RobustScaler()
rd=rs.fit_transform(d1)
sns.boxplot(data=rd,color="#C40707")
# Out:
# <Axes: >
